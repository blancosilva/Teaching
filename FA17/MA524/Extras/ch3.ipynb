# %%
from sympy.abc import x,y,z
from sympy import Matrix, solve, exp, simplify, factor, prod, log
from sympy.tensor.array import derive_by_array, Array

from sympy import init_printing

init_printing()

# %%
f = exp(x**2+y**2+z**2) - x**4 -y**6 -z**6
gradient = derive_by_array(f, [x,y,z])  # Use %time to see how fast this computes
hessian  = Matrix( [derive_by_array(gradient, a) for a in [x,y,z]])

# %%
gradient
# Out:
# ⎡               2    2    2                 2    2    2                 2    2
# ⎢     3        x  + y  + z        5        x  + y  + z        5        x  + y
# ⎣- 4⋅x  + 2⋅x⋅ℯ              - 6⋅y  + 2⋅y⋅ℯ              - 6⋅z  + 2⋅z⋅ℯ
#
#     2⎤
#  + z ⎥
#      ⎦

# %%
gradient.subs({x:0,y:0,z:0})
# Out:
# [0  0  0]

# %%
hessian
# Out:
# ⎡       2    2    2               2    2    2                       2    2
# ⎢   2  x  + y  + z        2      x  + y  + z                       x  + y  + z
# ⎢4⋅x ⋅ℯ             - 12⋅x  + 2⋅ℯ                           4⋅x⋅y⋅ℯ
# ⎢
# ⎢                    2    2    2                                2    2    2
# ⎢                   x  + y  + z                      4      2  x  + y  + z
# ⎢            4⋅x⋅y⋅ℯ                           - 30⋅y  + 4⋅y ⋅ℯ             +
# ⎢
# ⎢                    2    2    2                                    2    2
# ⎢                   x  + y  + z                                    x  + y  + z
# ⎣            4⋅x⋅z⋅ℯ                                        4⋅y⋅z⋅ℯ
#
# 2                                     2    2    2              ⎤
#                                      x  + y  + z               ⎥
#                               4⋅x⋅z⋅ℯ                          ⎥
#                                                                ⎥
#     2    2    2                       2    2    2              ⎥
#    x  + y  + z                       x  + y  + z               ⎥
# 2⋅ℯ                           4⋅y⋅z⋅ℯ                          ⎥
#                                                                ⎥
# 2                                 2    2    2       2    2    2⎥
#                        4      2  x  + y  + z       x  + y  + z ⎥
#                  - 30⋅z  + 4⋅z ⋅ℯ             + 2⋅ℯ            ⎦

# %%
hessian.subs({x:0,y:0,z:0})
# Out:
# ⎡2  0  0⎤
# ⎢       ⎥
# ⎢0  2  0⎥
# ⎢       ⎥
# ⎣0  0  2⎦

# %%
def f(x): return x**2-2

# %%
import numpy as np, matplotlib.pyplot as plt
plt.xkcd();

# %%
def search(f,fd,x0,steps):
    outputx=[x0,x0]
    outputy=[0,f(x0)]
    for step in range(steps):
        xn = x0-f(x0)/fd(x0)
        outputx.append(xn)
        outputx.append(xn)
        outputy.append(0)
        outputy.append(f(xn))
        x0 = xn
    return (outputx, outputy)

# %%
ox,oy = search(f,lambda x: 2*x,3,2)
# print(ox)

x=np.linspace(1,3)
plt.figure()
plt.plot([1,3],[0,0],'k')
plt.plot(ox,oy,'r')
plt.plot(x,f(x))
plt.plot(ox,np.zeros_like(ox),'or')
plt.plot(ox,[f(t) for t in ox],'or')
plt.text(3,-0.75,'3',color='r')
plt.text(1.83,-0.75,'1.833',color='r')
plt.text(1.4621,-0.75,'1.4621',color='r')
plt.text(2.5,6,'f(x)')
plt.title('First three steps')
plt.show()

# %%
ox,oy = search(f,lambda x: 2*x,1.46,3)
print(ox)
print(oy)
x=np.linspace(1.41,1.47)
plt.figure()
plt.plot([1.41,1.47],[0,0],'k')
plt.plot(x,f(x))
plt.plot(ox,oy,'r')
plt.plot(ox,np.zeros_like(ox),'or')
# plt.text(3,-0.75,'3',color='r')
# plt.text(1.83,-0.75,'1.833',color='r')
# plt.text(1.4621,-0.75,'1.4621',color='r')
# plt.text(2.5,6,'f(x)')
plt.show()
# Out:
# [1.46, 1.46, 1.4149315068493151, 1.4149315068493151, 1.4142137445176965, 1.4142137445176965, 1.4142135623731067, 1.4142135623731067]
# [0, 0.13159999999999972, 0, 0.002031169074873329, 0, 5.151827648930407e-07, 0, 3.2862601528904634e-14]

# %%
def search_output(f,fd,x0,steps):
    output = '\\begin{tabular}{|c|c|c|} \\hline \n'
    output += '$n$ & $x_n$ & $f(x_n)$ \\\\ \hline \hline \n'
    output += ('$0$ & $%1.15f$ & $%1.4E$ \\\\ \\hline \n' % (x0, f(x0)))
#     outputx=[x0,x0]
#     outputy=[0,f(x0)]
    for step in range(steps):
        xn = x0-f(x0)/fd(x0)
#         outputx.append(xn)
#         outputx.append(xn)
#         outputy.append(0)
#         outputy.append(f(xn))
        x0 = xn
        output += '$%d$ & $%1.15f$ & $%1.4E$ \\\\ \\hline \n' % (step+1,xn,f(xn)) 
                      
    
    output += r'\end{tabular}'
    return output

# %%
print(search_output(f,lambda x: 2*x, 3,7))
# Out:
# \begin{tabular}{|c|c|c|} \hline
# $n$ & $x_n$ & $f(x_n)$ \\ \hline \hline
# $0$ & $3.000000000000000$ & $7.0000E+00$ \\ \hline
# $1$ & $1.833333333333333$ & $1.3611E+00$ \\ \hline
# $2$ & $1.462121212121212$ & $1.3780E-01$ \\ \hline
# $3$ & $1.414998429894803$ & $2.2206E-03$ \\ \hline
# $4$ & $1.414213780047198$ & $6.1568E-07$ \\ \hline
# $5$ & $1.414213562373112$ & $4.7518E-14$ \\ \hline
# $6$ & $1.414213562373095$ & $-4.4409E-16$ \\ \hline
# $7$ & $1.414213562373095$ & $4.4409E-16$ \\ \hline
# \end{tabular}

# %%
def f(x): return 1-1/x

# %%
ox,oy=search(f, lambda x: 1/x**2,3,1)

# %%
x=np.linspace(0.2,4)
plt.figure()
plt.plot([-3.2,4],[0,0],'k')
plt.plot(x,f(x))
plt.plot(ox[:-1],oy[:-1],'r')
plt.plot(ox,np.zeros_like(ox),'or')
plt.text(3,-0.5,'3',color='r')
plt.text(-3,-0.5,'??',color='r')
# plt.text(1.4621,-0.75,'1.4621',color='r')
# plt.text(2.5,6,'f(x)')
plt.title("If the initial guess is not correct,\n the method will not work!")
plt.show()

# %%
def f(x): return np.sign(x)*abs(x)**(0.5)

# %%
ox,oy = search(f, lambda x: abs(x)**(-0.5)/2,1,2)

# %%
x = np.linspace(-2,2)
plt.figure()
plt.plot([-2,2],[0,0],'k')
plt.plot([0,0],[-1.5,1.5],'k')
plt.plot(ox,oy,'r',lw=0.4)
plt.plot(x,f(x))
plt.plot(ox,oy,'ro')
plt.title('We got ourselves a loop!')
plt.show()

# %%
def f(x): return abs(x)**0.5

# %%
ox,oy = search(f, lambda x: np.sign(x)*abs(x)**(-0.5)/2, 1, 2)

x = np.linspace(-2,2)
plt.figure()
plt.plot([-2,2],[0,0],'k')
plt.plot([0,0],[0,1.5],'k')
plt.plot(ox,oy,'r',lw=0.4)
plt.plot(x,f(x))
plt.plot(ox,oy,'ro')
plt.title('We got ourselves a loop!')
plt.show()

# %%
def f(x): return 9 - 4/(x-7)

# %%
ox,oy = search(f, lambda x: 4/(x-7)**2, 7.87, 5)

# %%
x = np.linspace(7.2,9)

plt.figure()
plt.plot(x,f(x))
plt.ylim(-4,10)
plt.plot([7,9],[0,0],'k')
plt.plot(ox,oy,'r')
plt.plot(ox,oy,'ro')
plt.show()

# %%
g=9-4/(y-7)

# %%
solve(y-g/g.diff())
# Out:
# ⎡  2⋅√67   67  2⋅√67   67⎤
# ⎢- ───── + ──, ───── + ──⎥
# ⎣    9     9     9     9 ⎦

# %%
nwtn = prod([y-a for a in solve(y-g/g.diff())])

# %%
nwtn
# Out:
# ⎛    67   2⋅√67⎞ ⎛    67   2⋅√67⎞
# ⎜y - ── - ─────⎟⋅⎜y - ── + ─────⎟
# ⎝    9      9  ⎠ ⎝    9      9  ⎠

# %%
def f(x): return 1-1/x
def g(x): return x-np.log(x)

ox1,oy1 = search(f, lambda x: 1/x**2, 0.888, 5)
ox2,oy2 = search(f, lambda x: 1/x**2, 1.8, 5)

x = np.linspace(0.35,2)

plt.figure(figsize=(8,8))
plt.subplot(223)
plt.plot(x,f(x))
plt.text(1.5,0.15,"f'(x)")
plt.plot([0.35,2],[0,0],'k')
plt.plot(ox1,oy1,'r')
plt.plot(ox1,oy1,'ro')
plt.subplot(224)
plt.plot(x,f(x))
plt.plot([0.5,2],[0,0],'k')
plt.plot(ox2,oy2,'r')
plt.plot(ox2,oy2,'ro')
plt.subplot(221)
plt.title('Quadratic Convergence\n guaranteed in (8/9, 10/9)')
plt.text(1.5,0.9,'f(x)')
plt.plot(x,g(x))
plt.plot([0.35,2],[0,0],'k')
plt.plot(ox1,[g(k) for k in ox1],'r')
plt.plot(ox1,[g(k) for k in ox1],'ro')
plt.subplot(222)
plt.title('Quadratic Convergence\n not guaranteed outside')
plt.plot(x,g(x))
plt.plot([0.35,2],[0,0],'k')
plt.plot(ox2,[g(k) for k in ox2],'r')
plt.plot(ox2,[g(k) for k in ox2],'ro')
plt.show()

# %%
[a.evalf() for a in solve(nwtn)]
# Out:
# [5.62547716180612, 9.26341172708277]

# %%
f =9*y-4*log(y-7)
gradient = derive_by_array(f, y)
hessian = derive_by_array(gradient, y)

# %%
xstar = solve(gradient)[0]

# %%
factor(hessian-hessian.subs({y:xstar}))
# Out:
# -(9⋅y - 67)⋅(9⋅y - 59)
# ───────────────────────
#                 2
#        4⋅(y - 7)

# %%
print(search(lambda x: np.sin(x), lambda x: np.cos(x), 3,5))
# Out:
# ([3, 3, 3.1425465430742778, 3.1425465430742778, 3.141592653300477, 3.141592653300477, 3.1415926535897931, 3.1415926535897931, 3.1415926535897931, 3.1415926535897931, 3.1415926535897931, 3.1415926535897931], [0, 0.14112000805986721, 0, -0.00095388933982644083, 0, 2.8931624907621843e-10, 0, 1.2246467991473532e-16, 0, 1.2246467991473532e-16, 0, 1.2246467991473532e-16])

# %%
print(search(lambda x: -1+np.log(x), lambda x: 1/x, 2, 5))
# Out:
# ([2, 2, 2.6137056388801092, 2.6137056388801092, 2.7162439263557903, 2.7162439263557903, 2.7182810643581381, 2.7182810643581381, 2.7182818284589376, 2.7182818284589376, 2.7182818284590455, 2.7182818284590455], [0, -0.30685281944005471, 0, -0.039231000595620125, 0, -0.00074998345420362877, 0, -2.8109705418888353e-07, 0, -3.9634961979118088e-14, 0, 0.0])

# %%
np.e
# Out:
# 2.718281828459045
