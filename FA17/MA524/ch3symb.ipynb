# %%
from sympy.abc import x,y,z
from sympy import Matrix, solve, exp
from sympy.tensor.array import derive_by_array

# %%
from sympy import init_printing
init_printing()

# %%
f = Matrix([x**3-y,y**3-x])
A = Matrix(2,2,derive_by_array([x**3-y,y**3-x], [x,y]))
B = A.inv()

# %%
G = Matrix([x,y])-B*f
G[1]
# Out:
#    2 ⎛      3⎞            3
# 3⋅x ⋅⎝-x + y ⎠           x  - y
# ────────────── + y + ─────────────
#      2  2                 2  2
# - 9⋅x ⋅y  + 1        - 9⋅x ⋅y  + 1

# %%
def recursive_output(x0,y0,steps):
    output  = "\\begin{tabular}{|c|c|c|} \\hline \n"
    output += "$n$ & $x_n$ & $y_n$ \\\\ \hline \hline \n"
    output += ("$0$ & $%1.8f$ & $%1.8f$ \\\\ \\hline \n" % (x0, y0))
    for step in range(steps):
        xn,yn=G.subs({x:x0, y:y0})
        output += ("$%d$ & $%1.8f$ & $%1.8f$ \\\\ \\hline \n" % (step+1, xn, yn))
        x0,y0=xn,yn
    output += "\end{tabular}"
    return output

# %%
print(recursive_output(-1,1,6))
# Out:
# \begin{tabular}{|c|c|c|} \hline
# $n$ & $x_n$ & $y_n$ \\ \hline \hline
# $0$ & $-1.00000000$ & $1.00000000$ \\ \hline
# $1$ & $-0.50000000$ & $0.50000000$ \\ \hline
# $2$ & $-0.14285714$ & $0.14285714$ \\ \hline
# $3$ & $-0.00549451$ & $0.00549451$ \\ \hline
# $4$ & $-0.00000033$ & $0.00000033$ \\ \hline
# $5$ & $-0.00000000$ & $0.00000000$ \\ \hline
# $6$ & $-0.00000000$ & $0.00000000$ \\ \hline
# \end{tabular}

# %%
def recursive(x0,y0,steps):
    outputx = [x0]
    outputy = [y0]
    for step in range(steps):
        xn,yn = G.subs({x:x0, y:y0})
        outputx.append(xn)
        outputy.append(yn)
        x0,y0 = xn,yn
    return outputx, outputy

# %%
ox1,oy1=recursive(3.5,2.1,7)
ox2,oy2=recursive(-3.9,-2.3,9)
ox3,oy3 = recursive(-1,1,6)

# %%
f = exp(x**2+y**2+z**2)-x**4-y**6-z**6
g = Matrix(derive_by_array(f, [x,y,z]))
A = Matrix(3,3,derive_by_array(g, [x,y,z]))
B = A.inv()
G = Matrix([x,y,z])-B*g

# %%
def recursive_output(x0,y0,z0,steps):
    output  = "\\begin{tabular}{|c|c|c|c|} \\hline \n"
    output += "$n$ & $x_n$ & $y_n$ & $z_n$ \\\\ \hline \hline \n"
    output += ("$0$ & $%1.8f$ & $%1.8f$ & $%1.8f$ \\\\ \\hline \n" % (x0, y0, z0))
    for step in range(steps):
        xn,yn,zn = G.subs({x:x0, y:y0, z:z0})
        output += ("$%d$ & $%1.8f$ & $%1.8f$ & $%1.8f$ \\\\ \\hline \n" % (step+1, xn, yn, zn))
        x0,y0,z0=xn,yn,zn
    output += "\end{tabular}"
    return output

# %%
print(recursive_output(1.,1.,1.,9))
# Out:
# \begin{tabular}{|c|c|c|c|} \hline
# $n$ & $x_n$ & $y_n$ & $z_n$ \\ \hline \hline
# $0$ & $1.00000000$ & $1.00000000$ & $1.00000000$ \\ \hline
# $1$ & $0.87757993$ & $0.85756618$ & $0.85756618$ \\ \hline
# $2$ & $0.80822356$ & $0.66100376$ & $0.66100376$ \\ \hline
# $3$ & $0.81585148$ & $0.38490335$ & $0.38490335$ \\ \hline
# $4$ & $0.51838857$ & $0.25646126$ & $0.25646126$ \\ \hline
# $5$ & $-0.12918157$ & $0.18918835$ & $0.18918835$ \\ \hline
# $6$ & $-0.01305885$ & $0.02674117$ & $0.02674117$ \\ \hline
# $7$ & $-0.00003282$ & $0.00008518$ & $0.00008518$ \\ \hline
# $8$ & $-0.00000000$ & $0.00000000$ & $0.00000000$ \\ \hline
# $9$ & $-0.00000000$ & $0.00000000$ & $0.00000000$ \\ \hline
# \end{tabular}

# %%
def recursive(x0,y0,z0,steps):
    outputx = [x0]
    outputy = [y0]
    outputz = [z0]
    for step in range(steps):
        xn,yn,zn = G.subs({x:x0, y:y0, z:z0})
        outputx.append(xn)
        outputy.append(yn)
        outputz.append(zn)
        x0,y0,z0 = xn,yn,zn
    return outputx, outputy, outputz

# %%
ox,oy,oz = recursive(1.,1.,1.,9)

# %%
# Out:
# [1.0, 0.877579928632525, 0.808223556941361, 0.815851475221461, 0.518388570398356, -0.129181572319677, -0.0130588511695029, -3.28166715809830e-5, -8.81743900723181e-13, -1.24366842844406e-35]

# %%
import numpy as np, matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

plt.xkcd();

# %%
x = np.linspace(-4,4)
y = np.linspace(-4,4)
X,Y = np.meshgrid(x,y)

plt.figure()
plt.axes(aspect='equal')
CS = plt.contour(X, Y, X**4-4*X*Y+Y**4, colors='k')
plt.clabel(CS, fontsize=9, inline=1)
plt.plot(ox1,oy1,'r')
plt.plot(ox1,oy1,'or')
plt.plot(ox2,oy2,'b')
plt.plot(ox2,oy2,'ob')
plt.plot(ox3,oy3,'g')
plt.plot(ox3,oy3,'og')
plt.title("Convergence to critical points: \nPolynomial")
plt.show()

# %%
# x = np.linspace(-2,2)
# y = np.linspace(-2,2)
# z = np.linspace(-2,2)
# X,Y,Z = np.meshgrid()

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot(ox,oy,oz,'o-')
plt.title("Searching critical points")
plt.show()
